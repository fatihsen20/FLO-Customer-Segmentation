# %% [markdown]
# # RFM ile Müşteri Segmentasyonu (Customer Segmentation with RFM)
#
# 1. İş Problemi (Business Problem)
# 2. Veriyi Anlama (Data Understanding)
# 3. Veri Hazırlama (Data Preparation)
# 4. RFM Metriklerinin Hesaplanması (Calculating RFM Metrics)
# 5. RFM Skorlarının Hesaplanması (Calculating RFM Scores)
# 6. RFM Segmentlerinin Oluşturulması ve Analiz Edilmesi (Creating & Analysing RFM Segments)
# 7. Tüm Sürecin Fonksiyonlaştırılması

# %%
import datetime as dt
import pandas as pd
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df_ = pd.read_csv("flo_data_20k.csv")
df = df_.copy()

# %%
df.head()
# Out:
#                               master_id order_channel last_order_channel  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
#
#   first_order_date last_order_date last_order_date_online  \
# 0       2020-10-30      2021-02-26             2021-02-21
# 1       2017-02-08      2021-02-16             2021-02-16
# 2       2019-11-27      2020-11-27             2020-11-27
# 3       2021-01-06      2021-01-17             2021-01-17
# 4       2019-08-03      2021-03-07             2021-03-07
#
#   last_order_date_offline  order_num_total_ever_online  \
# 0              2021-02-26                        4.000
# 1              2020-01-10                       19.000
# 2              2019-12-01                        3.000
# 3              2021-01-06                        1.000
# 4              2019-08-03                        1.000
#
#    order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                         1.000                            139.990
# 1                         2.000                            159.970
# 2                         2.000                            189.970
# 3                         1.000                             39.990
# 4                         1.000                             49.990
#
#    customer_value_total_ever_online       interested_in_categories_12
# 0                           799.380                           [KADIN]
# 1                          1853.580  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                           395.350                    [ERKEK, KADIN]
# 3                            81.980               [AKTIFCOCUK, COCUK]
# 4                           159.990                       [AKTIFSPOR]

# %%
df.columns
# Out:
# Index(['master_id', 'order_channel', 'last_order_channel', 'first_order_date',
#        'last_order_date', 'last_order_date_online', 'last_order_date_offline',
#        'order_num_total_ever_online', 'order_num_total_ever_offline',
#        'customer_value_total_ever_offline', 'customer_value_total_ever_online',
#        'interested_in_categories_12'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19945 entries, 0 to 19944
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   master_id                          19945 non-null  object
#  1   order_channel                      19945 non-null  object
#  2   last_order_channel                 19945 non-null  object
#  3   first_order_date                   19945 non-null  object
#  4   last_order_date                    19945 non-null  object
#  5   last_order_date_online             19945 non-null  object
#  6   last_order_date_offline            19945 non-null  object
#  7   order_num_total_ever_online        19945 non-null  float64
#  8   order_num_total_ever_offline       19945 non-null  float64
#  9   customer_value_total_ever_offline  19945 non-null  float64
#  10  customer_value_total_ever_online   19945 non-null  float64
#  11  interested_in_categories_12        19945 non-null  object
# dtypes: float64(4), object(8)
# memory usage: 1.8+ MB

# %%
df.describe().T
# Out:
#                                       count    mean     std    min     25%  \
# order_num_total_ever_online       19945.000   3.111   4.226  1.000   1.000
# order_num_total_ever_offline      19945.000   1.914   2.063  1.000   1.000
# customer_value_total_ever_offline 19945.000 253.923 301.533 10.000  99.990
# customer_value_total_ever_online  19945.000 497.322 832.602 12.990 149.980
#
#                                       50%     75%       max
# order_num_total_ever_online         2.000   4.000   200.000
# order_num_total_ever_offline        1.000   2.000   109.000
# customer_value_total_ever_offline 179.980 319.970 18119.140
# customer_value_total_ever_online  286.460 578.440 45220.130

# %%
df.isnull().sum()
# Out:
# master_id                            0
# order_channel                        0
# last_order_channel                   0
# first_order_date                     0
# last_order_date                      0
# last_order_date_online               0
# last_order_date_offline              0
# order_num_total_ever_online          0
# order_num_total_ever_offline         0
# customer_value_total_ever_offline    0
# customer_value_total_ever_online     0
# interested_in_categories_12          0
# dtype: int64

# %%
df["TotalEver"] = df["order_num_total_ever_online"] + df["order_num_total_ever_offline"]
df["TotalEverValue"] = df["customer_value_total_ever_offline"] + df["customer_value_total_ever_online"]

# %%
df.head()
# Out:
#                               master_id order_channel last_order_channel  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
#
#   first_order_date last_order_date last_order_date_online  \
# 0       2020-10-30      2021-02-26             2021-02-21
# 1       2017-02-08      2021-02-16             2021-02-16
# 2       2019-11-27      2020-11-27             2020-11-27
# 3       2021-01-06      2021-01-17             2021-01-17
# 4       2019-08-03      2021-03-07             2021-03-07
#
#   last_order_date_offline  order_num_total_ever_online  \
# 0              2021-02-26                        4.000
# 1              2020-01-10                       19.000
# 2              2019-12-01                        3.000
# 3              2021-01-06                        1.000
# 4              2019-08-03                        1.000
#
#    order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                         1.000                            139.990
# 1                         2.000                            159.970
# 2                         2.000                            189.970
# 3                         1.000                             39.990
# 4                         1.000                             49.990
#
#    customer_value_total_ever_online       interested_in_categories_12  \
# 0                           799.380                           [KADIN]
# 1                          1853.580  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                           395.350                    [ERKEK, KADIN]
# 3                            81.980               [AKTIFCOCUK, COCUK]
# 4                           159.990                       [AKTIFSPOR]
#
#    TotalEver  TotalEverValue
# 0      5.000         939.370
# 1     21.000        2013.550
# 2      5.000         585.320
# 3      2.000         121.970
# 4      2.000         209.980

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19945 entries, 0 to 19944
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   master_id                          19945 non-null  object
#  1   order_channel                      19945 non-null  object
#  2   last_order_channel                 19945 non-null  object
#  3   first_order_date                   19945 non-null  object
#  4   last_order_date                    19945 non-null  object
#  5   last_order_date_online             19945 non-null  object
#  6   last_order_date_offline            19945 non-null  object
#  7   order_num_total_ever_online        19945 non-null  float64
#  8   order_num_total_ever_offline       19945 non-null  float64
#  9   customer_value_total_ever_offline  19945 non-null  float64
#  10  customer_value_total_ever_online   19945 non-null  float64
#  11  interested_in_categories_12        19945 non-null  object
#  12  TotalEver                          19945 non-null  float64
#  13  TotalEverValue                     19945 non-null  float64
# dtypes: float64(6), object(8)
# memory usage: 2.1+ MB

# %%
date_columns = df.columns[df.columns.str.contains("date")]
df[date_columns] = df[date_columns].apply(pd.to_datetime)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19945 entries, 0 to 19944
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   master_id                          19945 non-null  object
#  1   order_channel                      19945 non-null  object
#  2   last_order_channel                 19945 non-null  object
#  3   first_order_date                   19945 non-null  datetime64[ns]
#  4   last_order_date                    19945 non-null  datetime64[ns]
#  5   last_order_date_online             19945 non-null  datetime64[ns]
#  6   last_order_date_offline            19945 non-null  datetime64[ns]
#  7   order_num_total_ever_online        19945 non-null  float64
#  8   order_num_total_ever_offline       19945 non-null  float64
#  9   customer_value_total_ever_offline  19945 non-null  float64
#  10  customer_value_total_ever_online   19945 non-null  float64
#  11  interested_in_categories_12        19945 non-null  object
#  12  TotalEver                          19945 non-null  float64
#  13  TotalEverValue                     19945 non-null  float64
# dtypes: datetime64[ns](4), float64(6), object(4)
# memory usage: 2.1+ MB

# %%
# Alışveriş kanallarındaki müşteri sayısının, toplam alınan ürün sayısı ve toplam harcamaların dağılımı.
df.groupby("order_channel").agg({"master_id": "count",
                                 "TotalEver": "sum",
                                 "TotalEverValue": "sum"})
# Out:
#                master_id  TotalEver  TotalEverValue
# order_channel
# Android App         9495  52269.000     7819062.760
# Desktop             2735  10920.000     1610321.460
# Ios App             2833  15351.000     2525999.930
# Mobile              4882  21679.000     3028183.160

# %%
df.describe().T
# Out:
#                                       count    mean     std    min     25%  \
# order_num_total_ever_online       19945.000   3.111   4.226  1.000   1.000
# order_num_total_ever_offline      19945.000   1.914   2.063  1.000   1.000
# customer_value_total_ever_offline 19945.000 253.923 301.533 10.000  99.990
# customer_value_total_ever_online  19945.000 497.322 832.602 12.990 149.980
# TotalEver                         19945.000   5.025   4.743  2.000   3.000
# TotalEverValue                    19945.000 751.244 895.402 44.980 339.980
#
#                                       50%     75%       max
# order_num_total_ever_online         2.000   4.000   200.000
# order_num_total_ever_offline        1.000   2.000   109.000
# customer_value_total_ever_offline 179.980 319.970 18119.140
# customer_value_total_ever_online  286.460 578.440 45220.130
# TotalEver                           4.000   6.000   202.000
# TotalEverValue                    545.270 897.780 45905.100

# %%
df.sort_values("TotalEverValue", ascending=False).head(10)
# Out:
#                                   master_id order_channel last_order_channel  \
# 11150  5d1c466a-9cfd-11e9-9897-000d3a38a36f   Android App            Desktop
# 4315   d5ef8058-a5c6-11e9-a2fc-000d3a38a36f   Android App        Android App
# 7613   73fd19aa-9e37-11e9-9897-000d3a38a36f       Ios App            Offline
# 13880  7137a5c0-7aad-11ea-8f20-000d3a38a36f       Ios App            Offline
# 9055   47a642fe-975b-11eb-8c2a-000d3a38a36f   Android App            Offline
# 7330   a4d534a2-5b1b-11eb-8dbd-000d3a38a36f       Desktop            Desktop
# 8068   d696c654-2633-11ea-8e1c-000d3a38a36f       Ios App            Ios App
# 163    fef57ffa-aae6-11e9-a2fc-000d3a38a36f        Mobile            Desktop
# 7223   cba59206-9dd1-11e9-9897-000d3a38a36f   Android App        Android App
# 18767  fc0ce7a4-9d87-11e9-9897-000d3a38a36f       Desktop            Desktop
#
#       first_order_date last_order_date last_order_date_online  \
# 11150       2013-10-11      2021-04-30             2021-04-30
# 4315        2018-08-06      2021-02-23             2021-02-23
# 7613        2014-01-14      2021-05-18             2021-01-30
# 13880       2021-03-01      2021-04-13             2021-03-18
# 9055        2021-04-07      2021-04-27             2021-04-07
# 7330        2020-02-16      2021-04-30             2021-04-30
# 8068        2017-05-10      2021-04-13             2021-04-13
# 163         2016-11-08      2021-05-12             2021-05-12
# 7223        2013-02-21      2021-05-09             2021-05-09
# 18767       2018-11-24      2020-11-11             2020-11-11
#
#       last_order_date_offline  order_num_total_ever_online  \
# 11150              2020-12-24                      200.000
# 4315               2020-07-06                       67.000
# 7613               2021-05-18                       81.000
# 13880              2021-04-13                       10.000
# 9055               2021-04-27                        1.000
# 7330               2020-12-18                       66.000
# 8068               2019-08-15                       69.000
# 163                2020-07-09                       36.000
# 7223               2020-01-25                      130.000
# 18767              2019-12-06                       18.000
#
#        order_num_total_ever_offline  customer_value_total_ever_offline  \
# 11150                         2.000                            684.970
# 4315                          1.000                            130.490
# 7613                          1.000                           1263.760
# 13880                         1.000                            538.940
# 9055                          3.000                          18119.140
# 7330                          4.000                            843.680
# 8068                          1.000                             82.480
# 163                           1.000                            180.730
# 7223                          1.000                             49.990
# 18767                         2.000                             64.970
#
#        customer_value_total_ever_online  \
# 11150                         45220.130
# 4315                          36687.800
# 7613                          32654.340
# 13880                         30688.470
# 9055                           2587.200
# 7330                          17599.890
# 8068                          16836.090
# 163                           12545.370
# 7223                          12232.250
# 18767                         12038.180
#
#                         interested_in_categories_12  TotalEver  TotalEverValue
# 11150  [AKTIFCOCUK, ERKEK, COCUK, KADIN, AKTIFSPOR]    202.000       45905.100
# 4315          [AKTIFCOCUK, ERKEK, KADIN, AKTIFSPOR]     68.000       36818.290
# 7613               [ERKEK, COCUK, KADIN, AKTIFSPOR]     82.000       33918.100
# 13880                     [ERKEK, KADIN, AKTIFSPOR]     11.000       31227.410
# 9055                                    [AKTIFSPOR]      4.000       20706.340
# 7330                      [ERKEK, KADIN, AKTIFSPOR]     70.000       18443.570
# 8068   [AKTIFCOCUK, ERKEK, COCUK, KADIN, AKTIFSPOR]     70.000       16918.570
# 163                              [ERKEK, AKTIFSPOR]     37.000       12726.100
# 7223          [AKTIFCOCUK, ERKEK, KADIN, AKTIFSPOR]    131.000       12282.240
# 18767                                [ERKEK, KADIN]     20.000       12103.150

# %%
df.sort_values("TotalEver", ascending=False).head(10)
# Out:
#                                   master_id order_channel last_order_channel  \
# 11150  5d1c466a-9cfd-11e9-9897-000d3a38a36f   Android App            Desktop
# 7223   cba59206-9dd1-11e9-9897-000d3a38a36f   Android App        Android App
# 8783   a57f4302-b1a8-11e9-89fa-000d3a38a36f   Android App            Offline
# 2619   fdbe8304-a7ab-11e9-a2fc-000d3a38a36f   Android App            Offline
# 6322   329968c6-a0e2-11e9-a2fc-000d3a38a36f       Ios App            Ios App
# 7613   73fd19aa-9e37-11e9-9897-000d3a38a36f       Ios App            Offline
# 9347   44d032ee-a0d4-11e9-a2fc-000d3a38a36f        Mobile             Mobile
# 10954  b27e241a-a901-11e9-a2fc-000d3a38a36f        Mobile             Mobile
# 8068   d696c654-2633-11ea-8e1c-000d3a38a36f       Ios App            Ios App
# 7330   a4d534a2-5b1b-11eb-8dbd-000d3a38a36f       Desktop            Desktop
#
#       first_order_date last_order_date last_order_date_online  \
# 11150       2013-10-11      2021-04-30             2021-04-30
# 7223        2013-02-21      2021-05-09             2021-05-09
# 8783        2019-08-07      2020-11-04             2020-09-07
# 2619        2018-10-18      2020-06-30             2018-10-18
# 6322        2019-02-14      2021-04-05             2021-04-05
# 7613        2014-01-14      2021-05-18             2021-01-30
# 9347        2019-02-11      2021-02-11             2021-02-11
# 10954       2015-09-12      2021-04-01             2021-04-01
# 8068        2017-05-10      2021-04-13             2021-04-13
# 7330        2020-02-16      2021-04-30             2021-04-30
#
#       last_order_date_offline  order_num_total_ever_online  \
# 11150              2020-12-24                      200.000
# 7223               2020-01-25                      130.000
# 8783               2020-11-04                        2.000
# 2619               2020-06-30                        1.000
# 6322               2020-02-17                        2.000
# 7613               2021-05-18                       81.000
# 9347               2020-12-24                        3.000
# 10954              2019-10-08                       72.000
# 8068               2019-08-15                       69.000
# 7330               2020-12-18                       66.000
#
#        order_num_total_ever_offline  customer_value_total_ever_offline  \
# 11150                         2.000                            684.970
# 7223                          1.000                             49.990
# 8783                        109.000                          10239.460
# 2619                         87.000                           8432.250
# 6322                         81.000                           3997.550
# 7613                          1.000                           1263.760
# 9347                         74.000                           4640.770
# 10954                         3.000                            292.930
# 8068                          1.000                             82.480
# 7330                          4.000                            843.680
#
#        customer_value_total_ever_online  \
# 11150                         45220.130
# 7223                          12232.250
# 8783                            143.980
# 2619                            139.980
# 6322                            242.810
# 7613                          32654.340
# 9347                            543.280
# 10954                          5004.950
# 8068                          16836.090
# 7330                          17599.890
#
#                         interested_in_categories_12  TotalEver  TotalEverValue
# 11150  [AKTIFCOCUK, ERKEK, COCUK, KADIN, AKTIFSPOR]    202.000       45905.100
# 7223          [AKTIFCOCUK, ERKEK, KADIN, AKTIFSPOR]    131.000       12282.240
# 8783   [AKTIFCOCUK, ERKEK, COCUK, KADIN, AKTIFSPOR]    111.000       10383.440
# 2619                                        [ERKEK]     88.000        8572.230
# 6322                                        [ERKEK]     83.000        4240.360
# 7613               [ERKEK, COCUK, KADIN, AKTIFSPOR]     82.000       33918.100
# 9347                             [KADIN, AKTIFSPOR]     77.000        5184.050
# 10954         [AKTIFCOCUK, ERKEK, KADIN, AKTIFSPOR]     75.000        5297.880
# 8068   [AKTIFCOCUK, ERKEK, COCUK, KADIN, AKTIFSPOR]     70.000       16918.570
# 7330                      [ERKEK, KADIN, AKTIFSPOR]     70.000       18443.570

# %%
def pre_proccesing(df):
    df.dropna(inplace=True)
    df["TotalEver"] = df["order_num_total_ever_online"] + df["order_num_total_ever_offline"]
    df["TotalEverValue"] = df["customer_value_total_ever_offline"] + df["customer_value_total_ever_online"]
    date_columns = df.columns[df.columns.str.contains("date")]
    df[date_columns] = df[date_columns].apply(pd.to_datetime)
    return df

# %%
df = pre_proccesing(df_)

# %%
df.head()
# Out:
#                               master_id order_channel last_order_channel  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
#
#   first_order_date last_order_date last_order_date_online  \
# 0       2020-10-30      2021-02-26             2021-02-21
# 1       2017-02-08      2021-02-16             2021-02-16
# 2       2019-11-27      2020-11-27             2020-11-27
# 3       2021-01-06      2021-01-17             2021-01-17
# 4       2019-08-03      2021-03-07             2021-03-07
#
#   last_order_date_offline  order_num_total_ever_online  \
# 0              2021-02-26                        4.000
# 1              2020-01-10                       19.000
# 2              2019-12-01                        3.000
# 3              2021-01-06                        1.000
# 4              2019-08-03                        1.000
#
#    order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                         1.000                            139.990
# 1                         2.000                            159.970
# 2                         2.000                            189.970
# 3                         1.000                             39.990
# 4                         1.000                             49.990
#
#    customer_value_total_ever_online       interested_in_categories_12  \
# 0                           799.380                           [KADIN]
# 1                          1853.580  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                           395.350                    [ERKEK, KADIN]
# 3                            81.980               [AKTIFCOCUK, COCUK]
# 4                           159.990                       [AKTIFSPOR]
#
#    TotalEver  TotalEverValue
# 0      5.000         939.370
# 1     21.000        2013.550
# 2      5.000         585.320
# 3      2.000         121.970
# 4      2.000         209.980

# %% [markdown]
# RFM Metriklerinin Hesaplanması

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19945 entries, 0 to 19944
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   master_id                          19945 non-null  object
#  1   order_channel                      19945 non-null  object
#  2   last_order_channel                 19945 non-null  object
#  3   first_order_date                   19945 non-null  datetime64[ns]
#  4   last_order_date                    19945 non-null  datetime64[ns]
#  5   last_order_date_online             19945 non-null  datetime64[ns]
#  6   last_order_date_offline            19945 non-null  datetime64[ns]
#  7   order_num_total_ever_online        19945 non-null  float64
#  8   order_num_total_ever_offline       19945 non-null  float64
#  9   customer_value_total_ever_offline  19945 non-null  float64
#  10  customer_value_total_ever_online   19945 non-null  float64
#  11  interested_in_categories_12        19945 non-null  object
#  12  TotalEver                          19945 non-null  float64
#  13  TotalEverValue                     19945 non-null  float64
# dtypes: datetime64[ns](4), float64(6), object(4)
# memory usage: 2.1+ MB

# %%
df["last_order_date"].max()
# Out:
# Timestamp('2021-05-30 00:00:00')

# %%
today_date = dt.datetime(2021, 6, 1)

# %%
rfm = df.groupby("master_id").agg({"last_order_date": lambda date: (today_date - date.max()).days,
                                    "TotalEver": lambda num: num.sum(),
                                    "TotalEverValue": lambda price: price.sum()})

# %%
rfm.head()
# Out:
#                                       last_order_date  TotalEver  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f               10      5.000
# 00034aaa-a838-11e9-a2fc-000d3a38a36f              298      3.000
# 000be838-85df-11ea-a90b-000d3a38a36f              213      4.000
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f               27      7.000
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f               20      7.000
#
#                                       TotalEverValue
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f         776.070
# 00034aaa-a838-11e9-a2fc-000d3a38a36f         269.470
# 000be838-85df-11ea-a90b-000d3a38a36f         722.690
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f         874.160
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f        1620.330

# %%
rfm.columns = ["recency", "frequency", "monetary"]

# %%
rfm.head()
# Out:
#                                       recency  frequency  monetary
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f       10      5.000   776.070
# 00034aaa-a838-11e9-a2fc-000d3a38a36f      298      3.000   269.470
# 000be838-85df-11ea-a90b-000d3a38a36f      213      4.000   722.690
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f       27      7.000   874.160
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f       20      7.000  1620.330

# %%
rfm.describe().T
# Out:
#               count    mean     std    min     25%     50%     75%       max
# recency   19945.000 134.458 103.281  2.000  43.000 111.000 202.000   367.000
# frequency 19945.000   5.025   4.743  2.000   3.000   4.000   6.000   202.000
# monetary  19945.000 751.244 895.402 44.980 339.980 545.270 897.780 45905.100

# %%
rfm = rfm[(rfm["monetary"]) > 0 & (rfm["frequency"] > 0)]

# %%
rfm["recency_score"] = pd.qcut(rfm["recency"], 5, labels = [5,4,3,2,1])
rfm["frequency_score"] = pd.qcut(rfm["frequency"].rank(method="first"), 5, labels = [1,2,3,4,5])
rfm["monetary_score"] = pd.qcut(rfm["monetary"], 5, labels = [1,2,3,4,5])

# %%
rfm.head()
# Out:
#                                       recency  frequency  monetary  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f       10      5.000   776.070
# 00034aaa-a838-11e9-a2fc-000d3a38a36f      298      3.000   269.470
# 000be838-85df-11ea-a90b-000d3a38a36f      213      4.000   722.690
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f       27      7.000   874.160
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f       20      7.000  1620.330
#
#                                      recency_score frequency_score  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f             5               4
# 00034aaa-a838-11e9-a2fc-000d3a38a36f             1               2
# 000be838-85df-11ea-a90b-000d3a38a36f             2               3
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f             5               4
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f             5               4
#
#                                      monetary_score
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f              4
# 00034aaa-a838-11e9-a2fc-000d3a38a36f              1
# 000be838-85df-11ea-a90b-000d3a38a36f              4
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f              4
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f              5

# %%
rfm["RFM_SCORE"] = (rfm["recency_score"].astype(str) + rfm["frequency_score"].astype(str) + rfm["monetary_score"].astype(str))
rfm["RF_SCORE"] = (rfm["recency_score"].astype(str) + rfm["frequency_score"].astype(str))

# %%
rfm.head()
# Out:
#                                       recency  frequency  monetary  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f       10      5.000   776.070
# 00034aaa-a838-11e9-a2fc-000d3a38a36f      298      3.000   269.470
# 000be838-85df-11ea-a90b-000d3a38a36f      213      4.000   722.690
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f       27      7.000   874.160
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f       20      7.000  1620.330
#
#                                      recency_score frequency_score  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f             5               4
# 00034aaa-a838-11e9-a2fc-000d3a38a36f             1               2
# 000be838-85df-11ea-a90b-000d3a38a36f             2               3
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f             5               4
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f             5               4
#
#                                      monetary_score RFM_SCORE RF_SCORE
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f              4       544       54
# 00034aaa-a838-11e9-a2fc-000d3a38a36f              1       121       12
# 000be838-85df-11ea-a90b-000d3a38a36f              4       234       23
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f              4       544       54
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f              5       545       54

# %% [markdown]
# RFM Segmentlerinin Yapılması

# %%
seg_map = {
    r'[1-2][1-2]': 'hibernating',
    r'[1-2][3-4]': 'at_Risk',
    r'[1-2]5': 'cant_loose',
    r'3[1-2]': 'about_to_sleep',
    r'33': 'need_attention',
    r'[3-4][4-5]': 'loyal_customers',
    r'41': 'promising',
    r'51': 'new_customers',
    r'[4-5][2-3]': 'potential_loyalists',
    r'5[4-5]': 'champions'
}

# %%
rfm["segment"] = rfm["RF_SCORE"].replace(seg_map, regex=True)

# %%
rfm.head()
# Out:
#                                       recency  frequency  monetary  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f       10      5.000   776.070
# 00034aaa-a838-11e9-a2fc-000d3a38a36f      298      3.000   269.470
# 000be838-85df-11ea-a90b-000d3a38a36f      213      4.000   722.690
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f       27      7.000   874.160
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f       20      7.000  1620.330
#
#                                      recency_score frequency_score  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f             5               4
# 00034aaa-a838-11e9-a2fc-000d3a38a36f             1               2
# 000be838-85df-11ea-a90b-000d3a38a36f             2               3
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f             5               4
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f             5               4
#
#                                      monetary_score RFM_SCORE RF_SCORE  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f              4       544       54
# 00034aaa-a838-11e9-a2fc-000d3a38a36f              1       121       12
# 000be838-85df-11ea-a90b-000d3a38a36f              4       234       23
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f              4       544       54
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f              5       545       54
#
#                                           segment
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f    champions
# 00034aaa-a838-11e9-a2fc-000d3a38a36f  hibernating
# 000be838-85df-11ea-a90b-000d3a38a36f      at_Risk
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f    champions
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f    champions

# %%
rfm.reset_index(inplace=True)

# %%
rfm.head()
# Out:
#                               master_id  recency  frequency  monetary  \
# 0  00016786-2f5a-11ea-bb80-000d3a38a36f       10      5.000   776.070
# 1  00034aaa-a838-11e9-a2fc-000d3a38a36f      298      3.000   269.470
# 2  000be838-85df-11ea-a90b-000d3a38a36f      213      4.000   722.690
# 3  000c1fe2-a8b7-11ea-8479-000d3a38a36f       27      7.000   874.160
# 4  000f5e3e-9dde-11ea-80cd-000d3a38a36f       20      7.000  1620.330
#
#   recency_score frequency_score monetary_score RFM_SCORE RF_SCORE      segment
# 0             5               4              4       544       54    champions
# 1             1               2              1       121       12  hibernating
# 2             2               3              4       234       23      at_Risk
# 3             5               4              4       544       54    champions
# 4             5               4              5       545       54    champions

# %%
rfm[["segment","recency","frequency","monetary"]].groupby("segment").agg(["mean","count"])
# Out:
#                     recency       frequency       monetary
#                        mean count      mean count     mean count
# segment
# about_to_sleep      114.032  1643     2.407  1643  361.649  1643
# at_Risk             242.329  3152     4.470  3152  648.325  3152
# cant_loose          235.159  1194    10.717  1194 1481.652  1194
# champions            17.142  1920     8.965  1920 1410.709  1920
# hibernating         247.426  3589     2.391  3589  362.583  3589
# loyal_customers      82.558  3375     8.356  3375 1216.257  3375
# need_attention      113.037   806     3.739   806  553.437   806
# new_customers        17.976   673     2.000   673  344.049   673
# potential_loyalists  36.870  2925     3.311  2925  533.741  2925
# promising            58.695   668     2.000   668  334.153   668

# %%
#Merge with interested category
df_interested = df[["master_id","interested_in_categories_12"]]
rfm = pd.merge(rfm, df_interested, on="master_id", how="left")

# %%
rfm.head()
# Out:
#                               master_id  recency  frequency  monetary  \
# 0  00016786-2f5a-11ea-bb80-000d3a38a36f       10      5.000   776.070
# 1  00034aaa-a838-11e9-a2fc-000d3a38a36f      298      3.000   269.470
# 2  000be838-85df-11ea-a90b-000d3a38a36f      213      4.000   722.690
# 3  000c1fe2-a8b7-11ea-8479-000d3a38a36f       27      7.000   874.160
# 4  000f5e3e-9dde-11ea-80cd-000d3a38a36f       20      7.000  1620.330
#
#   recency_score frequency_score monetary_score RFM_SCORE RF_SCORE  \
# 0             5               4              4       544       54
# 1             1               2              1       121       12
# 2             2               3              4       234       23
# 3             5               4              4       544       54
# 4             5               4              5       545       54
#
#        segment                   interested_in_categories_12
# 0    champions                     [ERKEK, COCUK, AKTIFSPOR]
# 1  hibernating                                [ERKEK, KADIN]
# 2      at_Risk                       [AKTIFCOCUK, AKTIFSPOR]
# 3    champions  [AKTIFCOCUK, ERKEK, COCUK, KADIN, AKTIFSPOR]
# 4    champions                            [ERKEK, AKTIFSPOR]

# %%
cust_id = rfm[(rfm["segment"].isin(["champions","loyal_customers"])) & (rfm["interested_in_categories_12"].str.contains("KADIN"))]["master_id"]

# %%
cust_id.to_csv("yeni_urun_hedef_musteri_id.csv",index=False)

# %%
# Geçmişte iyi ama şimdi fazla alışveriş yapmayan müşteriler
sale_customers = rfm[(rfm["segment"].isin(["cant_loose","hibernating","at_Risk","new_customers","about_to_sleep"])) &((rfm["interested_in_categories_12"].str.contains("ERKEK"))|(rfm["interested_in_categories_12"].str.contains("COCUK")))]["master_id"]

# %%
sale_customers.to_csv("indirim_hedef_musteri_id.csv",index=False)

# %% [markdown]
# Çalışmanın Scripti

# %%
def create_rfm(df):
    df.dropna(inplace=True)
    df["TotalEver"] = df["order_num_total_ever_online"] + df["order_num_total_ever_offline"]
    df["TotalEverValue"] = df["customer_value_total_ever_offline"] + df["customer_value_total_ever_online"]
    date_columns = df.columns[df.columns.str.contains("date")]
    df[date_columns] = df[date_columns].apply(pd.to_datetime)

    today_date = dt.datetime(2021, 6, 1)
    rfm = df.groupby("master_id").agg({"last_order_date": lambda date: (today_date - date.max()).days,
                                    "TotalEver": lambda num: num.sum(),
                                    "TotalEverValue": lambda price: price.sum()})
    rfm.columns = ["recency", "frequency", "monetary"]
    rfm = rfm[(rfm["monetary"]) > 0 & (rfm["frequency"] > 0)]

    rfm["recency_score"] = pd.qcut(rfm["recency"], 5, labels = [5,4,3,2,1])
    rfm["frequency_score"] = pd.qcut(rfm["frequency"].rank(method="first"), 5, labels = [1,2,3,4,5])
    rfm["monetary_score"] = pd.qcut(rfm["monetary"], 5, labels = [1,2,3,4,5])

    rfm["RFM_SCORE"] = (rfm["recency_score"].astype(str) + rfm["frequency_score"].astype(str) + rfm["monetary_score"].astype(str))
    rfm["RF_SCORE"] = (rfm["recency_score"].astype(str) + rfm["frequency_score"].astype(str))

    seg_map = {
    r'[1-2][1-2]': 'hibernating',
    r'[1-2][3-4]': 'at_Risk',
    r'[1-2]5': 'cant_loose',
    r'3[1-2]': 'about_to_sleep',
    r'33': 'need_attention',
    r'[3-4][4-5]': 'loyal_customers',
    r'41': 'promising',
    r'51': 'new_customers',
    r'[4-5][2-3]': 'potential_loyalists',
    r'5[4-5]': 'champions'
    }

    rfm["segment"] = rfm["RF_SCORE"].replace(seg_map, regex=True)
    rfm.reset_index(inplace=True)

    df_interested = df[["master_id","interested_in_categories_12"]]
    rfm = pd.merge(rfm, df_interested, on="master_id", how="left")

    return rfm

# %%
new_rfm = create_rfm(df_)

# %%
new_rfm
# Out:
#                                   master_id  recency  frequency  monetary  \
# 0      00016786-2f5a-11ea-bb80-000d3a38a36f       10      5.000   776.070
# 1      00034aaa-a838-11e9-a2fc-000d3a38a36f      298      3.000   269.470
# 2      000be838-85df-11ea-a90b-000d3a38a36f      213      4.000   722.690
# 3      000c1fe2-a8b7-11ea-8479-000d3a38a36f       27      7.000   874.160
# 4      000f5e3e-9dde-11ea-80cd-000d3a38a36f       20      7.000  1620.330
# ...                                     ...      ...        ...       ...
# 19940  fff1db94-afd9-11ea-b736-000d3a38a36f      183      5.000   796.870
# 19941  fff4736a-60a4-11ea-8dd8-000d3a38a36f       67      2.000   318.870
# 19942  fffacd34-ae14-11e9-a2fc-000d3a38a36f      257      6.000   983.920
# 19943  fffacecc-ddc3-11e9-a848-000d3a38a36f      132      9.000  1362.200
# 19944  fffe4b30-18e0-11ea-9213-000d3a38a36f      321      4.000   524.690
#
#       recency_score frequency_score monetary_score RFM_SCORE RF_SCORE  \
# 0                 5               4              4       544       54
# 1                 1               2              1       121       12
# 2                 2               3              4       234       23
# 3                 5               4              4       544       54
# 4                 5               4              5       545       54
# ...             ...             ...            ...       ...      ...
# 19940             2               4              4       244       24
# 19941             4               2              2       422       42
# 19942             1               4              4       144       14
# 19943             3               5              5       355       35
# 19944             1               4              3       143       14
#
#                    segment                   interested_in_categories_12
# 0                champions                     [ERKEK, COCUK, AKTIFSPOR]
# 1              hibernating                                [ERKEK, KADIN]
# 2                  at_Risk                       [AKTIFCOCUK, AKTIFSPOR]
# 3                champions  [AKTIFCOCUK, ERKEK, COCUK, KADIN, AKTIFSPOR]
# 4                champions                            [ERKEK, AKTIFSPOR]
# ...                    ...                                           ...
# 19940              at_Risk                                   [AKTIFSPOR]
# 19941  potential_loyalists                                            []
# 19942              at_Risk                                       [ERKEK]
# 19943      loyal_customers                     [COCUK, KADIN, AKTIFSPOR]
# 19944              at_Risk                                [ERKEK, KADIN]
#
# [19945 rows x 11 columns]
